# %%
import pandas as pd
import numpy as np

# %%
# read csv as df
df = pd.read_csv("data_modelling.csv")

# %%
df.head()
# Out:
#    Record ID Company Name Industry  Carbon Emissions (MT)  Water Usage (m^3)  \
# 0        1.0    Company_1       IT                41648.0           165790.0
# 1        3.0    Company_3       IT                 3973.0           450035.0
# 2       27.0   Company_27       IT                23731.0           627683.0
# 3       33.0   Company_33       IT                49146.0           335918.0
# 4       35.0   Company_35       IT                47481.0            21277.0
#
#    Energy Consumption (MWh)  Waste Generation (MT)  Recycling Rate (%)  \
# 0                   41851.0                11163.0               65.85
# 1                   34379.0                 9787.0               27.06
# 2                    2598.0                12142.0               31.14
# 3                   43623.0                 5646.0               46.68
# 4                   10315.0                15032.0               28.02
#
#    Supply Chain Sustainability Score Employee Transportation Mode  ...  \
# ...

# %%
numeric_cols = df.select_dtypes(include=[np.number])                                                # Extract numeric columns
numeric_cols = numeric_cols.drop(['Record ID'], axis=1)
df[numeric_cols.columns] = numeric_cols.apply(lambda x: (x - np.mean(x)) / (np.max(x) - np.min(x))) # min-max normalization
df.head()
# Out:
#    Record ID Company Name Industry  Carbon Emissions (MT)  Water Usage (m^3)  \
# 0        1.0    Company_1       IT               0.332973          -0.341798
# 1        3.0    Company_3       IT              -0.435968          -0.054628
# 2       27.0   Company_27       IT              -0.032710           0.124848
# 3       33.0   Company_33       IT               0.486006          -0.169919
# 4       35.0   Company_35       IT               0.452023          -0.487799
#
#    Energy Consumption (MWh)  Waste Generation (MT)  Recycling Rate (%)  \
# 0                  0.329837              -0.065882            0.264203
# 1                  0.177300              -0.122056           -0.382297
# 2                 -0.471490              -0.025914           -0.314297
# 3                  0.366011              -0.291111           -0.055297
# 4                 -0.313952               0.092069           -0.366297
#
#    Supply Chain Sustainability Score Employee Transportation Mode  ...  \
# ...

# %%
# save as csv
df.to_csv("data_normalized.csv")
